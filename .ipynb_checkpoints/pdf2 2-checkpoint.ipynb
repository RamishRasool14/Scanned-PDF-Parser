# %%
import numpy as np
from PIL import Image
import PIL
import cv2
from pdf2image import convert_from_path
import math
import string
import json as j
import io
from google.cloud import vision_v1
import sys



def boundary(image):
    if isinstance(image,PIL.PpmImagePlugin.PpmImageFile):
        image = np.array(image)
    r,c,_ = image.shape
    dd = BreakPoints(image[int(r*0.77):,:],0,x = int(c/2))
    ll = [ dd[i+1] - dd[i] for i in range(len( dd )-1)  ]
    
    image = image[:dd[ll.index(max(ll))]+int(r*0.77),:]
    r,c,_ = image.shape
    image = cv2.line(image,(0,0),(0,r),(255,255,255),30)
    image = cv2.line(image,(0,0),(c,0),(255,255,255),30)
    image = cv2.line(image,(0,r),(c,r),(255,255,255),30)
    image = cv2.line(image,(c,0),(c,r),(255,255,255),30)
    
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)
    thresh = cv2.threshold(blurred, 160,255,cv2.THRESH_BINARY_INV)[1]
    gray = np.float32(thresh)
    dst = cv2.cornerHarris(gray,2,3,0.04)
    indices = np.argwhere((dst>0.01*dst.max()) == True)
    distances = np.linalg.norm(indices,axis = 1)
    sorted_distances = sorted(distances)
    start = indices[np.where(distances == sorted_distances[0] )[0][0],:]
    end = indices[np.where(distances == sorted_distances[-1] )[0][0],:]
    
    image = image[start[0]:end[0],start[1]:end[1]]
    
    return image

def detect(sec,path):
    file_path = path+".tiff"
    cv2.line(sec,(int(c*0.556749),0),(int(c*0.556749),r),(0,0,0),6)
    cv2.imwrite(file_path,sec)
    client = vision_v1.ImageAnnotatorClient()
    mime_type = "image/tiff"
    with io.open(file_path, "rb") as f:
        content = f.read()
    input_config = {"mime_type": mime_type, "content": content}
    features = [{"type_": vision_v1.Feature.Type.DOCUMENT_TEXT_DETECTION}]

    pages = [1, 2, -1]
    requests = [{"input_config": input_config, "features": features, "pages": pages}]

    response = client.batch_annotate_files(requests=requests)
    LIST = []
    for image_response in response.responses[0].responses:
        for page in image_response.full_text_annotation.pages:
            for block in page.blocks:
                for par in block.paragraphs:
                    for word in par.words:
                        wor = []
                        for symbol in word.symbols:
                            wor.append(symbol.text)
                        LIST.append( ( [[v.x,v.y] for v in word.bounding_box.vertices],"".join(wor)) )
    return LIST


def blockIsIn(block,v):
    for x in block:
        if not isIn(x,v):
            return False
    return True

def isIn(p,v):
    return p[0]>v[0][0]-5 and p[0]<v[1][0]+5 and p[1]>v[0][1]-5 and p[1]<v[1][1]+5

def BreakPoints(a,adjust,x,total = None):
    r,c,_ = a.shape
    breakpoints = []
    breakpoints.append(0)
    change = False
    for row in range(0,a.shape[0]):
        if a[row,x,0] == 255:
            change = True
            
        if change and a[row,x,0] == 0:
            breakpoints.append(row-adjust)
            change = False
            if total is not None and len(breakpoints) == total:
                break
    return breakpoints   


def segmentation(a,d):
    r,c,_ = a.shape
    img = a.copy()
    img = cv2.blur(img , (10,3))
    img = np.where(img < 200 , 0,255)
    img = np.float32(img)
    
    l = []
    for x in range(0,img[:,1200,0].shape[0]-60):
        l.append(( (img[x:x+d,1200,0]/255).sum() , x))
    sort = sorted(l,key = lambda x: x[0],reverse = False)
    pts = [0]
    def toadd(pts,pt):
        for x in pts:
            if abs(pt-x) < 100:
                return False
        return True
    for (s,x) in sort:
        if toadd(pts,x) and s < 10:
            pts.append(x)
    breakpoints = sorted(pts)
    breakpoints.append(r)
    sections = []
    for ind in range(len(breakpoints)-1):
        prevp = breakpoints[ind]
        nextp = breakpoints[ind+1]
        if abs(prevp-nextp) > 100:
            sections.append(a[prevp:nextp,0:c])
    return sections,breakpoints




def draw(img,cords):
    r,c,_ = img.shape
    for (a,b) in cords:        
        img = cv2.circle(img,a,5,(255,0,0),-1)
        img = cv2.circle(img,b,5,(0,0,0),-1)
    plt.imshow(img)

def extractsec1(LIST,c,z):
    RATINGLIST = []
    STATEL = []
    STATE = [(int(0.76*c), int(0.376*z)), (int(0.883*c), int(0.549*z))]
    RISKID = [(int(0.88*c), int(0.173*z)), (int(1*c),int(0.35*z))]
    RATINGEFFECTIVE = [(int(0.279*c), int(0.387*z)), (int(0.371*c), int(0.56*z))]
    PRODUCTION = [(int(0.565*c),int(0.383*z)),(int(0.663*c),int(0.564*z))]
    RISKNAME = [(int(0.193*c), int(0.214*z)), (int(0.632*c),int(0.346*z))]
    STATECODE = [(int(0*c),int(0.719*z)),(int(0.1800*c),int(0.86*z))]
    CARRIER = [(int(0.07*c),int(0.88*z)),(int(0.135*c),int(1*z))]
    EFF_DATE = [(int(0.553*c),int(0.88*z)),(int(0.651*c),int(1*z))]
    EXP_DATE = [(int(0.803*c),int(0.88*z)),(int(0.9*c),int(1*z))]
    POLICYNO = [(int(0.26*c),int(0.88*z)),(int(0.43*c),int(1*z))]
    sec1list = [STATE,RISKID,RATINGEFFECTIVE,PRODUCTION,RISKNAME,STATECODE,CARRIER,EFF_DATE,EXP_DATE,POLICYNO]

    RISKLIST = []
    risk_name = ""
    risk_id = ""
    rating_effective_date = ""
    production_date = ""
    state = ""
    state_code = ""
    carrier = ""
    eff = ""
    exp = ""
    pol = ""
    for ind,x in enumerate(LIST):
        if blockIsIn(x[0],RISKID):
            risk_id = x[1]
        if blockIsIn(x[0],RATINGEFFECTIVE):
            RATINGLIST.append(x[1])
        if blockIsIn(x[0],RISKNAME):
            RISKLIST.append(x[1])
        if blockIsIn(x[0],PRODUCTION):
            production_date = x[1]
        if blockIsIn(x[0],STATE):
            state = x[1]            
        if blockIsIn(x[0],STATECODE):
            STATEL.append(x[1])
        if blockIsIn(x[0],CARRIER):
            carrier = x[1]
        if blockIsIn(x[0],EFF_DATE):
            eff = x[1]
        if blockIsIn(x[0],EXP_DATE):
            exp = x[1]
        if blockIsIn(x[0],POLICYNO):
            pol = x[1]
        
    rating_effective_date = [x for x in RATINGLIST if ("/" in x)][0]
    risk_name =  " ".join(RISKLIST)
    state_code = " ".join(STATEL)

    if risk_name == "":
        print("Risk Name Not Found")
    if risk_id == "":
        print("Risk ID Not Found")
    if rating_effective_date == "":
        print("Rating Effective Not Found")
    if production_date == "":
        print("Production Date Not Found")
    if state == "":
        print("State Not Found")
    if state_code == "":
        print("State Code Not Found")
    if carrier == "":
        print("Carrier Not Found")
    if eff == "":
        print("Eff Date Not Found")
    if exp == "":
        print("Exp Date Not Found")
    if pol == "":
        print("Policy Number Not Found")
        
    temp = {
                            "risk_name": cleant(risk_name),
                            "risk_id": risk_id,
                            "rating_effective_date": rating_effective_date,
                            "production_date": production_date,
                            "state": state,
                            "carrier": carrier,
                            "policy_no": pol,
                            "eff_date": eff,
                            "exp_date": exp,
                            "code": "",
                            "elr": "",
                            "dratio": "",
                            "payroll": "",
                            "expected_losses": "",
                            "exp_prim_losses": "",
                            "claim_data": "",
                            "ij": "",
                            "of": "",
                            "act_inc_losses": "",
                            "act_prim_losses": "",
                            "statecode": state_code,
                            "Policy Total": "",
                            "Subject Premium": "",
                            "Total Act Inc Losses": ""
                        }
    return temp

def extractsec3(x,data):
    exsec2 = data.copy()
    claim_data = x[6]
    code = x[0]
    try:
        ij = int(x[7])
    except:
        ij = ""
    of = x[8] if len(x[8]) == 1 else ""
    try:
        act_inc_losses = x[9].replace(".",",").replace(",","")
    except:
        act_inc_losses = ""

    try:
        act_prim_losses = int(x[10].replace(".",",").replace(",",""))
    except:
        act_prim_losses = ""

    try:
        payroll = int(x[3].replace(",",""))
    except:
        payroll = ""

    try:
        elr = float(x[1].replace(" ","").replace(",","."))
    except:
        elr = x[1]
    try:
        expected_losses = int(x[4].replace(",",""))
    except:
        expected_losses = ""  

    try:
        dratio = float("."+(x[2].replace(" ","").replace(",","").replace(".","")))
    except:
        dratio = ""
    try:
        exp_prim_losses = int(x[5].replace(",",""))
    except:
        exp_prim_losses = "" 
    exsec2["claim_data"] = claim_data.translate(str.maketrans('', '', '!"#%&\'()*+,-./:;<=>?@[\\]^_`{|}~'))
    exsec2["code"] = code
    exsec2["ij"] = str(ij)
    exsec2["of"] = of
    exsec2["act_inc_losses"] = str(act_inc_losses)
    exsec2["act_prim_losses"] = str(act_prim_losses)
    exsec2["payroll"] = str(payroll)
    exsec2["elr"] = str(elr)
    exsec2["expected_losses"] = expected_losses
    exsec2["dratio"] = str(dratio)
    exsec2["exp_prim_losses"] = exp_prim_losses
    exsec2["claim_data"] = claim_data
        
    return exsec2

def same(P,a,b):
    p = P.copy()
    r , c ,_= p.shape
    rm = 50
    wid = 20
    if c > 2500:
        rm = 100
        print("here")
    p = np.where(p < 170 , 0,255)
    a = cv2.blur(p , (a,1))
    a = np.where(a > rm , 255,0)
    
    a = cv2.line(np.float32(a), (0,0), (c, 0), (0, 0, 0), thickness=20)
    hlist = [BreakPoints(a,0,x) for x in range(0,c,10)]
    h = sorted(hlist, key = lambda x: len(x), reverse = True)[0]
    h.append(r)
    h = hcheck(h)
    a = cv2.blur(p , (1,b))
    a = np.where(a > rm , 255,0)
    line_thickness = 2
    for x in h:
        a = cv2.line(np.float32(a), (0, x), (c, x), (0, 0, 0), thickness=line_thickness)
    a = cv2.line(a, (0, 0), (0, r), (0, 0, 0), thickness=10)    
    a = cv2.line(a, (c,0), (c, r), (0, 0, 0), thickness=10)
    
    yy = []
    cords = []
    y = 0
    ignore_first = False
    for ind in range(1,len(h)):
        d = (h[ind] - h[ind-1])
        mid0 = int(h[ind-1] + (d/2) )
        mid1 = int(h[ind-1] + (d/4) )
        mid2 = int(h[ind-1] + (3*d/4) )
        sprev = 0
        MID = None
        for mid in [mid0,mid1,mid2]:
            s = 0
            temp_cords = []
            temp_yy = []
            for x in range(c):
                if a[mid,x].sum() == 0 and ignore_first and abs(y-x) > wid and abs(h[ind] - h[ind-1]) > 20:
                    if x < y:
                        y = x
                        continue
                    temp_cords.append([(y,h[ind-1]),(x,h[ind])])
                    name = np.uint8(P[h[ind-1]:h[ind],y:x,:])
                    temp_yy.append(name)
                    y = x
                elif a[mid,x].sum() == 0:
                    ignore_first = True
            if len(temp_yy) !=0 and len(temp_cords) != 0:
                s = s+len(temp_yy)
            if s > sprev:
                MID = mid
                sprev = s
                
        temp_cords = []
        temp_yy = []
        ignore_first = False
        for x in range(c):
            if a[MID,x].sum() == 0 and ignore_first and abs(y-x) > wid and abs(h[ind] - h[ind-1]) > 20:
                if x < y:
                    y = x
                    continue
                temp_cords.append([(y,h[ind-1]),(x,h[ind])])
                name = np.uint8(P[h[ind-1]:h[ind],y:x,:])
                temp_yy.append(name)
                y = x
            elif a[MID,x].sum() == 0:
                ignore_first = True
        if len(temp_yy) !=0 and len(temp_cords) != 0:
            yy.append(temp_yy)
            cords.append(temp_cords)
    
    return yy,cords,len(h)

def clean(t):
    return t.translate(str.maketrans('', '', '!"$%&\'()+/:;<=>?@[\\]^_`{|}~')).strip()
def cleant(t):
    return t.translate(str.maketrans('', '', string.punctuation)).strip()


def arrange(array):
    if len(array) == 1:
        return array
    ret = []
    intx = []
    for x in array:
        try:
            ret.append(intx.append(int(x)))
        except:
            ret.append(x)
    return ret
    
def extract3(text_detections_in_order,temp):    
    assert len(text_detections_in_order) <= 4
    for ind , x in enumerate(text_detections_in_order):
        if x != "":
            if ind == 0:
                poltotal = [int(word) for word in cleant(x).split() if word.isdigit()]
            if ind == 1:
                subprem = [int(word) for word in cleant(x).split() if word.isdigit()]
            if ind == 2:
                total_act_inc_loss = [int(word) for word in cleant(x).split() if word.isdigit()]
    try:
        polt = poltotal[0]
    except:
        polt = "0"
        
    try:
        subp = subprem[0]
    except:
        subp = "0"
        
    try:
        totala = total_act_inc_loss[0]
    except:
        totala = "0"
        
    temp["Policy Total"] = polt
    temp["Subject Premium"] = subp
    temp["Total Act Inc Losses"] = totala
    return temp
    
def extract4(LIST,data,r,c,b):
    temp = data.copy()
    CARRIER = [(c*0.07675,r-50+b),(c*0.14198,r+b)]
    POL = [(0.25864*c,r-50+b),(c*0.38373,r+b)]
    EFF = [(c*0.55488,r-50+b ),(c*0.65464,r+b)]
    EXP = [(c*0.801228,r-50+b),(0.90560*c,r+b)]
    STATECODE = [(0,r-100+b),(0.18*c,r-40+b)]
    
    ll = [CARRIER,POL,EFF,EXP,STATECODE]
    pol = ""
    carrier = ""
    eff = ""
    exp = ""
    state_code = ""
    STATEC = []
    EFFL = []
    EXPL = []
    
    
    for ind,x in enumerate(LIST):
        if blockIsIn(x[0],CARRIER):
            carrier = x[1]
        if blockIsIn(x[0],POL):
            pol = x[1]
        if blockIsIn(x[0],EFF):
            EFFL.append(x[1])
        if blockIsIn(x[0],EXP):
            EXPL.append(x[1])
        if blockIsIn(x[0],STATECODE):
            STATEC.append(x[1])
            
    state_code = "".join(STATEC)
    eff = "".join(EFFL)
    exp = "".join(EXPL)
    
    
    
    assert isinstance(carrier,str) and len(carrier) > 4
    assert isinstance(pol,str) and len(pol) > 4
    assert isinstance(eff,str) and len(eff) > 4
    assert isinstance(exp,str) and len(exp) > 4
    assert isinstance(state_code,str) and len(state_code) > 4

    temp["carrier"] = carrier
    temp["policy_no"] = pol
    temp["eff_date"] = eff
    temp["exp_date"] = exp
    temp["statecode"] = state_code
    return temp

def check1(text_detections_row):
    for x in text_detections_row:
        if "total" in x.lower().strip():
            return True
    return False

def hcheck(l):
    newl = [0]
    prev = newl[0]
    for x in range(1,len(l)):
        if abs(prev - l[x]) > 35:
            newl.append(l[x])
            prev = l[x]
    return newl
        
def secondpage(det):
    for (ptr,text) in det:
        if "stabiliz" in text.lower().strip():
            return True
    return False
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-1d04f0fc036a> in <module>
#       8 import json as j
#       9 import io
# ---> 10 from google.cloud import vision_v1
#      11 import sys
#      12
#
# C:\anaconda\lib\site-packages\google\cloud\vision_v1\__init__.py in <module>
#      15 #
#      16
# ---> 17 from google.cloud.vision_helpers.decorators import add_single_feature_methods
#      18 from google.cloud.vision_helpers import VisionHelpers
#      19
#
# C:\anaconda\lib\site-packages\google\cloud\vision_helpers\__init__.py in <module>
#      14
#      15 from __future__ import absolute_import
# ---> 16 import proto
#      17
#      18 from google.api_core import protobuf_helpers as protobuf
#
# ModuleNotFoundError: No module named 'proto'

# %%
# path = sys.argv[-2]
path = r"C:\Users\DANIYAL's PC\Desktop\Ramish\nirav9033688351-attachments\nirav9033688351-attachments\Ramirashool NCCI PDF task instructions\pdfs\scanned\specialchar.pdf"
pop_path = r"C:\Users\DANIYAL's PC\Desktop\Ramish\nirav9033688351-attachments\poppler-0.68.0_x86\poppler-0.68.0\bin"
json = {
            "id": "",
            "document_id": "",
            "remote_id": "",
            "file_name": path.split("/")[-1],
            "media_link": "",
            "media_link_original": "",
            "media_link_data": "",
            "page_count": "",
            "uploaded_at": "",
            "processed_at": "",
            "merged_amit_data_edit": []
}
im = convert_from_path(path,poppler_path=pop_path)
json["page_count"] = str(len(im))
json

# %%
temp_list = []
polFound = True
for page in range(1,int(json["page_count"])):
    bound = boundary(im[page])
    bound = cv2.cvtColor(bound, cv2.COLOR_RGB2GRAY)
    bound = cv2.cvtColor(bound, cv2.COLOR_GRAY2RGB)
    
    r,c,_ = bound.shape
    if c > 2500:
        print("resizing")
        bound = cv2.resize(bound, (1300,1670), interpolation = cv2.INTER_AREA)
        
    r,c,_ = bound.shape
    if r < 1300:
        r = 1670
    det = detect(bound,"page"+str(page))
    
    if secondpage(det):
        continue
    sta = 1
    secs,breakpoints = segmentation(bound,int(r*0.03588516746))
    if not polFound and len(det) < 50:
        det = detect( bound [BreakPoints(bound,0,c-50)[1]: ,:] ,"page"+str(page))
        inorderminus1 = []
        for _,x in det:
            try:
                x = int(x.replace(",",""))
                inorderminus1.append("ABC "+str(x))
            except:
                pass
        inorderminus1.append("")
        temp = extract3(inorderminus1,t)
        for x in range(len(temp_list)-1,-1,-1):
            if temp_list[x]["Policy Total"] == 10101010101:
                temp_list[x]["Policy Total"] = temp["Policy Total"]
                temp_list[x]["Subject Premium"] = temp["Subject Premium"]
                temp_list[x]["Total Act Inc Losses"] = temp["Total Act Inc Losses"]
            else:
                break
        polFound = True
        continue

    elif not polFound:
        B = bound [BreakPoints(bound,0,c-10)[1]: ,:]
        det = detect( B ,"page"+str(page))
        r,c,_ = B.shape
        secs,breakpoints = segmentation(B,int(r*0.03588516746))
        if secs[0].shape[0] > 320:
            sta = 0
    else:
        t = extractsec1(det,c,breakpoints[1])
    print(len(secs),"secs in page",page)

    for sec_n in range(sta,len(secs)):
        sec = secs[sec_n].copy()
        small_block,cords,hlen = same(sec,int(c*0.03846153846),int(c*0.02307692307))
        print("Sec",sec_n,"of page",page,"has",hlen-1,"rows")
        text_detections_in_order = []
        for indr,row in enumerate(cords):
            text_detections_row = []
            for indc, ((tlr,tlc),(brr,brc)) in enumerate(row):
                text_detections_col = []
                for ind_d, (block_detection,text) in enumerate(det):
                    if blockIsIn(block_detection,((tlr,tlc+breakpoints[sec_n]),(brr,brc+breakpoints[sec_n]))):
                        text_detections_col.append(text)
                to_add = clean(" ".join(text_detections_col))
                text_detections_row.append(to_add)
            if check1(text_detections_row):
                text_detections_in_order.append(text_detections_row)
                break            
            text_detections_in_order.append(text_detections_row)
        if len(text_detections_in_order[-1]) < 5:
            temp = extract3(text_detections_in_order[-1],t)
            for x in range(len(temp_list)-1,-1,-1):
                if temp_list[x]["Policy Total"] == 10101010101:
                    temp_list[x]["Policy Total"] = temp["Policy Total"]
                    temp_list[x]["Subject Premium"] = temp["Subject Premium"]
                    temp_list[x]["Total Act Inc Losses"] = temp["Total Act Inc Losses"]
                else:
                    break
            polFound = True
        else:
            text_detections_in_order.append(["a 10101010101","a 10101010101","a 10101010101",""])
            temp = extract3(text_detections_in_order[-1],t)
            polFound = False
        for x in range(1,len(text_detections_in_order)-1):
            row = text_detections_in_order[x]
            if len(row) != 11:
                row.insert(2,"")
                row.insert(3,"")
                temp1 = extractsec3(row,temp)
            else:
                temp1 = extractsec3(row,temp)
            temp_list.append(temp1)
        try:
            t = extract4( det,t,sec.shape[0],c,breakpoints[sec_n]).copy()
        except:
            pass

print( "Total Records Found:", len(temp_list))
json["merged_amit_data_edit"] = temp_list
json_base = []
json_base.append(json)
with open(sys.argv[-1]+"/"+path.split("/")[-1].split(".")[0]+'.json', 'w') as fp:
    j.dump(json_base, fp,indent = 4)
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-8-0c7f3d72272c> in <module>
#      20     if r < 1300:
#      21         r = 1670
# ---> 22     det = detect(bound,"page"+str(page))
#      23
#      24     if secondpage(det):
#
# <ipython-input-1-2b3fd8019273> in detect(sec, path)
#      56     file_path = path+".tiff"
#      57     cv2.imwrite(file_path,sec)
# ---> 58     client = vision_v1.ImageAnnotatorClient()
#      59     mime_type = "image/tiff"
#      60     with io.open(file_path, "rb") as f:
#
# C:\anaconda\lib\site-packages\google\cloud\vision_v1\services\image_annotator\client.py in __init__(self, credentials, transport, client_options, client_info)
#     358         else:
#     359             Transport = type(self).get_transport_class(transport)
# --> 360             self._transport = Transport(
#     361                 credentials=credentials,
#     362                 credentials_file=client_options.credentials_file,
#
# C:\anaconda\lib\site-packages\google\cloud\vision_v1\services\image_annotator\transports\grpc.py in __init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access)
#     152
#     153         # The base transport sets the host, credentials and scopes
# --> 154         super().__init__(
#     155             host=host,
#     156             credentials=credentials,
#
# C:\anaconda\lib\site-packages\google\cloud\vision_v1\services\image_annotator\transports\base.py in __init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, **kwargs)
#     117
#     118         elif credentials is None:
# --> 119             credentials, _ = google.auth.default(
#     120                 **scopes_kwargs, quota_project_id=quota_project_id
#     121             )
#
# C:\anaconda\lib\site-packages\google\auth\_default.py in default(scopes, request, quota_project_id, default_scopes)
#     457
#     458     for checker in checkers:
# --> 459         credentials, project_id = checker()
#     460         if credentials is not None:
#     461             credentials = with_scopes_if_required(
#
# C:\anaconda\lib\site-packages\google\auth\_default.py in <lambda>()
#     450         # safely set on the returned credentials since requires_scopes will
#     451         # guard against setting scopes on user credentials.
# --> 452         lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     453         lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     454         _get_gae_credentials,
#
# C:\anaconda\lib\site-packages\google\auth\_default.py in _get_explicit_environ_credentials(quota_project_id)
#     219
#     220     if explicit_file is not None:
# --> 221         credentials, project_id = load_credentials_from_file(
#     222             "C:\Users\DANIYAL's PC\Desktop\Ramish\nirav9033688351-attachments\nirav9033688351-attachments\psychic-binder-322102-86e070baffc0.json", quota_project_id=quota_project_id
#     223         )
#
# C:\anaconda\lib\site-packages\google\auth\_default.py in load_credentials_from_file(filename, scopes, default_scopes, quota_project_id, request)
#     103     """
#     104     if not os.path.exists(filename):
# --> 105         raise exceptions.DefaultCredentialsError(
#     106             "File {} was not found.".format(filename)
#     107         )
#
# DefaultCredentialsError: File C:\Users\DANIYAL's PC\Desktop\Ramish\nirav9033688351-attachments\nirav9033688351-attachments\psychic-binder-322102-86e070baffc0 was not found.

# %%
# for indr,row in enumerate(cords):
#     for indc, ((tlr,tlc),(brr,brc)) in enumerate(row):
#         print(indr,indc,((tlr,tlc),(brr,brc)))
temp_list
# Out:
# [{'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3509986',
#   'eff_date': '10/01/2015',
#   'exp_date': '10/01/2016',
#   'code': '8810',
#   'elr': '0.08',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 43,
#   'exp_prim_losses': '',
#   'claim_data': '102',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 296686,
#   'Subject Premium': 862,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3509986',
#   'eff_date': '10/01/2015',
#   'exp_date': '10/01/2016',
#   'code': '9765',
#   'elr': 'WORKPLACE SAFETY',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 5,
#   'exp_prim_losses': 2,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 296686,
#   'Subject Premium': 862,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3509986',
#   'eff_date': '10/01/2015',
#   'exp_date': '10/01/2016',
#   'code': '9812',
#   'elr': 'EMPLOYERS LIABILIT',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': 0,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 296686,
#   'Subject Premium': 862,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3509986',
#   'eff_date': '10/01/2015',
#   'exp_date': '10/01/2016',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 12,
#   'exp_prim_losses': 5,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 296686,
#   'Subject Premium': 862,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3509986',
#   'eff_date': '10/01/2015',
#   'exp_date': '10/01/2016',
#   'code': '9848',
#   'elr': 'MINIMUM PREMIUM FO',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': 0,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 296686,
#   'Subject Premium': 862,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '0005',
#   'elr': '2.23',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': '',
#   'exp_prim_losses': '',
#   'claim_data': '2,333',
#   'ij': '25156601',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '1092',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '0008',
#   'elr': '1.69',
#   'dratio': '0.39',
#   'payroll': '115506',
#   'expected_losses': 1952,
#   'exp_prim_losses': 761,
#   'claim_data': 'NO . 2',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '2207',
#   'act_prim_losses': '2207',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '0037',
#   'elr': '2.34',
#   'dratio': '0.39',
#   'payroll': '209481',
#   'expected_losses': 4902,
#   'exp_prim_losses': 1912,
#   'claim_data': '27732831',
#   'ij': '',
#   'of': 'F',
#   'act_inc_losses': '84149',
#   'act_prim_losses': '17000',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '0173',
#   'elr': '0.4',
#   'dratio': '0.45',
#   'payroll': '306387',
#   'expected_losses': 1226,
#   'exp_prim_losses': 552,
#   'claim_data': '27025471',
#   'ij': '',
#   'of': 'O',
#   'act_inc_losses': '460073',
#   'act_prim_losses': '17000',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '0930',
#   'elr': 'WAIVER OF SUBROGAT',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': 0,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '2105',
#   'elr': '2.13',
#   'dratio': '0.45',
#   'payroll': '182253',
#   'expected_losses': 3882,
#   'exp_prim_losses': 1747,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '2790',
#   'elr': '1.03',
#   'dratio': '0.45',
#   'payroll': '155720',
#   'expected_losses': 1604,
#   'exp_prim_losses': 722,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5022',
#   'elr': '3.85',
#   'dratio': '0.32',
#   'payroll': '2600',
#   'expected_losses': 100,
#   'exp_prim_losses': 32,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5183',
#   'elr': '1.68',
#   'dratio': '0.36',
#   'payroll': '118547',
#   'expected_losses': 1992,
#   'exp_prim_losses': 717,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5190',
#   'elr': '1.84',
#   'dratio': '0.36',
#   'payroll': '74848',
#   'expected_losses': 1377,
#   'exp_prim_losses': 496,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5191',
#   'elr': '47.0',
#   'dratio': '0.43',
#   'payroll': '118616',
#   'expected_losses': 557,
#   'exp_prim_losses': 240,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5221',
#   'elr': '2.76',
#   'dratio': '0.36',
#   'payroll': '168143',
#   'expected_losses': 4641,
#   'exp_prim_losses': 1671,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5223',
#   'elr': '2.32',
#   'dratio': '0.36',
#   'payroll': '216540',
#   'expected_losses': 5024,
#   'exp_prim_losses': 1809,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5348',
#   'elr': '1.78',
#   'dratio': '0.36',
#   'payroll': '3612',
#   'expected_losses': 64,
#   'exp_prim_losses': 23,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5445',
#   'elr': '2.8',
#   'dratio': '0.32',
#   'payroll': '64392',
#   'expected_losses': 1803,
#   'exp_prim_losses': 577,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5478',
#   'elr': '1.84',
#   'dratio': '0.36',
#   'payroll': '58836',
#   'expected_losses': 1083,
#   'exp_prim_losses': 390,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5537',
#   'elr': '2.3',
#   'dratio': '0.36',
#   'payroll': '92956',
#   'expected_losses': 2138,
#   'exp_prim_losses': 770,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '5645',
#   'elr': '6.07',
#   'dratio': '0.32',
#   'payroll': '111845',
#   'expected_losses': 6789,
#   'exp_prim_losses': 2172,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8017',
#   'elr': '0.77',
#   'dratio': '0.45',
#   'payroll': '5251',
#   'expected_losses': 40,
#   'exp_prim_losses': 18,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8018',
#   'elr': '1.43',
#   'dratio': '0.45',
#   'payroll': '210300',
#   'expected_losses': 3007,
#   'exp_prim_losses': 1353,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8033',
#   'elr': '0.89',
#   'dratio': '0.43',
#   'payroll': '76226',
#   'expected_losses': 678,
#   'exp_prim_losses': 292,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8045',
#   'elr': '0.32',
#   'dratio': '0.45',
#   'payroll': '309768',
#   'expected_losses': 991,
#   'exp_prim_losses': 446,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8232',
#   'elr': '1.87',
#   'dratio': '0.36',
#   'payroll': '25900',
#   'expected_losses': 484,
#   'exp_prim_losses': 174,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8380',
#   'elr': '1.26',
#   'dratio': '0.4',
#   'payroll': '208791',
#   'expected_losses': 2631,
#   'exp_prim_losses': 1052,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8721',
#   'elr': '0.1',
#   'dratio': '0.36',
#   'payroll': '85440',
#   'expected_losses': 85,
#   'exp_prim_losses': 31,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8742',
#   'elr': '0.14',
#   'dratio': '0.36',
#   'payroll': '213379',
#   'expected_losses': 299,
#   'exp_prim_losses': 108,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8810',
#   'elr': '0.08',
#   'dratio': '0.43',
#   'payroll': '1284602',
#   'expected_losses': 1028,
#   'exp_prim_losses': 442,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '8864',
#   'elr': '0.7',
#   'dratio': '0.43',
#   'payroll': '314139',
#   'expected_losses': 2199,
#   'exp_prim_losses': 946,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '9012',
#   'elr': '45.0',
#   'dratio': '0.4',
#   'payroll': '78540',
#   'expected_losses': 353,
#   'exp_prim_losses': 141,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '9014',
#   'elr': '1.8',
#   'dratio': '0.43',
#   'payroll': '155685',
#   'expected_losses': 2802,
#   'exp_prim_losses': 1205,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '9015',
#   'elr': '1.78',
#   'dratio': '43.0',
#   'payroll': '147603',
#   'expected_losses': 2627,
#   'exp_prim_losses': 1130,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '9063',
#   'elr': '0.54',
#   'dratio': '0.45',
#   'payroll': '547662',
#   'expected_losses': 2957,
#   'exp_prim_losses': 1331,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '9083',
#   'elr': '0.9',
#   'dratio': '0.49',
#   'payroll': '2400',
#   'expected_losses': 22,
#   'exp_prim_losses': 11,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '9084',
#   'elr': '0.91',
#   'dratio': '0.43',
#   'payroll': '10753',
#   'expected_losses': 98,
#   'exp_prim_losses': 42,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3586621',
#   'eff_date': '10/01/2016',
#   'exp_date': '10/01/2017',
#   'code': '9102',
#   'elr': '1.83',
#   'dratio': '0.43',
#   'payroll': '498698',
#   'expected_losses': 9126,
#   'exp_prim_losses': 3924,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 6418754,
#   'Subject Premium': 198585,
#   'Total Act Inc Losses': 547521},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '0005',
#   'elr': '2.23',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': '',
#   'exp_prim_losses': '',
#   'claim_data': '2,381',
#   'ij': '28536531',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '8257',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '0008',
#   'elr': '1.69',
#   'dratio': '0.39',
#   'payroll': '76409',
#   'expected_losses': 1291,
#   'exp_prim_losses': 503,
#   'claim_data': 'NO . 3',
#   'ij': '6',
#   'of': '',
#   'act_inc_losses': '3239',
#   'act_prim_losses': '3239',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '0037',
#   'elr': '2.34',
#   'dratio': '0.39',
#   'payroll': '127392',
#   'expected_losses': 2981,
#   'exp_prim_losses': 1163,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '0173',
#   'elr': '0.4',
#   'dratio': '0.45',
#   'payroll': '245870',
#   'expected_losses': 983,
#   'exp_prim_losses': 442,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '0930',
#   'elr': 'WAIVER OF SUBROGAT',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': 0,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '2105',
#   'elr': '2.13',
#   'dratio': '0.45',
#   'payroll': '116533',
#   'expected_losses': 2482,
#   'exp_prim_losses': 1117,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '2790',
#   'elr': '1.03',
#   'dratio': '0.45',
#   'payroll': '179950',
#   'expected_losses': 1853,
#   'exp_prim_losses': 834,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5022',
#   'elr': '3.85',
#   'dratio': '0.32',
#   'payroll': '15124',
#   'expected_losses': 582,
#   'exp_prim_losses': 186,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5183',
#   'elr': '1.68',
#   'dratio': '0.36',
#   'payroll': '145819',
#   'expected_losses': 2450,
#   'exp_prim_losses': 882,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5190',
#   'elr': '1.84',
#   'dratio': '0.36',
#   'payroll': '99644',
#   'expected_losses': 1833,
#   'exp_prim_losses': 660,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5191',
#   'elr': '0.47',
#   'dratio': '43.0',
#   'payroll': '51925',
#   'expected_losses': 244,
#   'exp_prim_losses': 105,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5221',
#   'elr': '2.76',
#   'dratio': '0.36',
#   'payroll': '119590',
#   'expected_losses': 3301,
#   'exp_prim_losses': 1188,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5223',
#   'elr': '2.32',
#   'dratio': '0.36',
#   'payroll': '104361',
#   'expected_losses': 2421,
#   'exp_prim_losses': 872,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5445',
#   'elr': '2.8',
#   'dratio': '0.32',
#   'payroll': '105207',
#   'expected_losses': 2946,
#   'exp_prim_losses': 943,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5478',
#   'elr': '1.84',
#   'dratio': '0.36',
#   'payroll': '146564',
#   'expected_losses': 2697,
#   'exp_prim_losses': 971,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5537',
#   'elr': '2.3',
#   'dratio': '0.36',
#   'payroll': '34551',
#   'expected_losses': 795,
#   'exp_prim_losses': 286,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '5645',
#   'elr': '6.07',
#   'dratio': '0.32',
#   'payroll': '118490',
#   'expected_losses': 7192,
#   'exp_prim_losses': 2301,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8018',
#   'elr': '1.43',
#   'dratio': '0.45',
#   'payroll': '246142',
#   'expected_losses': 3520,
#   'exp_prim_losses': 1584,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8033',
#   'elr': '0.89',
#   'dratio': '0.43',
#   'payroll': '120392',
#   'expected_losses': 1071,
#   'exp_prim_losses': 461,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8232',
#   'elr': '1.87',
#   'dratio': '0.36',
#   'payroll': '26000',
#   'expected_losses': 486,
#   'exp_prim_losses': 175,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8380',
#   'elr': '1.26',
#   'dratio': '0.4',
#   'payroll': '112761',
#   'expected_losses': 1421,
#   'exp_prim_losses': 568,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8721',
#   'elr': '0.1',
#   'dratio': '0.36',
#   'payroll': '86840',
#   'expected_losses': 87,
#   'exp_prim_losses': 31,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8742',
#   'elr': '0.14',
#   'dratio': '0.36',
#   'payroll': '70550',
#   'expected_losses': 99,
#   'exp_prim_losses': 36,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8810',
#   'elr': '0.08',
#   'dratio': '0.43',
#   'payroll': '1365773',
#   'expected_losses': 1093,
#   'exp_prim_losses': 470,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8864',
#   'elr': '0.7',
#   'dratio': '0.43',
#   'payroll': '321834',
#   'expected_losses': 2253,
#   'exp_prim_losses': 969,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8868',
#   'elr': '0.2',
#   'dratio': '0.45',
#   'payroll': '164127',
#   'expected_losses': 328,
#   'exp_prim_losses': 148,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9012',
#   'elr': '0.45',
#   'dratio': '0.4',
#   'payroll': '90158',
#   'expected_losses': 406,
#   'exp_prim_losses': 162,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9014',
#   'elr': '1.8',
#   'dratio': '0.43',
#   'payroll': '13700',
#   'expected_losses': 247,
#   'exp_prim_losses': 106,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9015',
#   'elr': '1.78',
#   'dratio': '0.43',
#   'payroll': '159695',
#   'expected_losses': 2843,
#   'exp_prim_losses': 1222,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9063',
#   'elr': '54.0',
#   'dratio': '0.45',
#   'payroll': '379011',
#   'expected_losses': 2047,
#   'exp_prim_losses': 921,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9084',
#   'elr': '0.91',
#   'dratio': '43.0',
#   'payroll': '22765',
#   'expected_losses': 207,
#   'exp_prim_losses': 89,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9093',
#   'elr': '0.91',
#   'dratio': '0.45',
#   'payroll': '255623',
#   'expected_losses': 2326,
#   'exp_prim_losses': 1047,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9102',
#   'elr': '1.83',
#   'dratio': '0.43',
#   'payroll': '305401',
#   'expected_losses': 5589,
#   'exp_prim_losses': 2403,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9664',
#   'elr': 'DEDUCTIBLE REPORTI',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': 0,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9765',
#   'elr': 'WORKPLACE SAFETY',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 1274,
#   'exp_prim_losses': 505,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 5676481,
#   'Subject Premium': 184950,
#   'Total Act Inc Losses': 11496},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026800',
#   'eff_date': '09/11/2016',
#   'exp_date': '09/11/2017',
#   'code': '0008',
#   'elr': '1.69',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': '',
#   'exp_prim_losses': '',
#   'claim_data': '358',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '20000',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 965906,
#   'Subject Premium': 47750,
#   'Total Act Inc Losses': 25173},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026800',
#   'eff_date': '09/11/2016',
# ...
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 5,
#   'exp_prim_losses': 2,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': '',
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 12,
#   'exp_prim_losses': 5,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 119,
#   'exp_prim_losses': 46,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 14,
#   'exp_prim_losses': 5,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 42,
#   'exp_prim_losses': 16,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 1,
#   'exp_prim_losses': 1,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 18,
#   'exp_prim_losses': 7,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 13,
#   'exp_prim_losses': 5,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 3,
#   'exp_prim_losses': '',
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 83,
#   'exp_prim_losses': '',
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 37,
#   'exp_prim_losses': '',
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 27,
#   'exp_prim_losses': 10,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 8,
#   'exp_prim_losses': 3,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 327,
#   'exp_prim_losses': '',
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 8,
#   'exp_prim_losses': 7,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 225,
#   'exp_prim_losses': 8,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': 0,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 379,
#   'exp_prim_losses': 145,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9841',
#   'elr': 'DRUG  FREE WORKPLAC',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 6,
#   'exp_prim_losses': 2,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 4619220,
#   'Subject Premium': 179466,
#   'Total Act Inc Losses': 96722},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '8018',
#   'elr': '1.16',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': '',
#   'exp_prim_losses': '',
#   'claim_data': '784',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 166657,
#   'Subject Premium': 3684,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '8810',
#   'elr': '0.07',
#   'dratio': '0.43',
#   'payroll': '16514',
#   'expected_losses': 12,
#   'exp_prim_losses': 5,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 166657,
#   'Subject Premium': 3684,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '30406',
#   'policy_no': 'TGW900026801',
#   'eff_date': '09/11/2017',
#   'exp_date': '09/11/2018',
#   'code': '9812',
#   'elr': 'EMPLOYERS LIABILIT',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': 0,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '09 - FLORIDA',
#   'Policy Total': 166657,
#   'Subject Premium': 3684,
#   'Total Act Inc Losses': '0'},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8018',
#   'elr': '1.16',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': '',
#   'exp_prim_losses': '',
#   'claim_data': '774',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '13 - INDIANA',
#   'Policy Total': 167338,
#   'Subject Premium': 3328,
#   'Total Act Inc Losses': 0},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '8810',
#   'elr': '0.07',
#   'dratio': '0.43',
#   'payroll': '18982',
#   'expected_losses': 13,
#   'exp_prim_losses': 6,
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '13 - INDIANA',
#   'Policy Total': 167338,
#   'Subject Premium': 3328,
#   'Total Act Inc Losses': 0},
#  {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#   'risk_id': '914245192',
#   'rating_effective_date': '09/11/2019',
#   'production_date': '07/25/2019',
#   'state': 'INTERSTATE',
#   'carrier': '39071',
#   'policy_no': 'TWC3665048',
#   'eff_date': '10/01/2017',
#   'exp_date': '10/01/2018',
#   'code': '9812',
#   'elr': 'EMPLOYERS LIABILIT',
#   'dratio': '',
#   'payroll': '',
#   'expected_losses': 0,
#   'exp_prim_losses': '',
#   'claim_data': '',
#   'ij': '',
#   'of': '',
#   'act_inc_losses': '',
#   'act_prim_losses': '',
#   'statecode': '13 - INDIANA',
#   'Policy Total': 167338,
#   'Subject Premium': 3328,
#   'Total Act Inc Losses': 0}]

# %%
bound = boundary(im[-2])

bound = cv2.cvtColor(bound, cv2.COLOR_RGB2GRAY)
bound = cv2.cvtColor(bound, cv2.COLOR_GRAY2RGB)
# print(BreakPoints(bound,0,c-10))
# bound = bound [BreakPoints(bound,0,c-10)[1]: ,:]
# bound = cv2.resize(bound, (1300,1670), interpolation = cv2.INTER_AREA)
r,c,_ = bound.shape
if r < 1300:
    r = 1670
det = detect(bound,"page"+str(1))
# print(r)
secs , breaks = segmentation(bound,int(r*0.03588516746))

# _,l = extractsec1(det,c,breaks[1])
# draw(bound,l)

# d = [(390, 49), (519, 72)]
# img = cv2.circle(bound,d[0],5,(255,0,0),-1)
# img = cv2.circle(img,d[1],5,(255,0,0),-1)
# plt.imshow(img)
# bound = np.where(bound< 170 , 0,255)
small_block,cords,hlen = same(secs[0],int(c*0.03846153846),int(c*0.02307692307))
# hlen
# plt.imshow(small_block[0][4])
# print(cords[2][0])
# bound = img

# ret, thresh = cv2.threshold(thresh, 127, 255, 0)
# b = cv2.blur(thresh , (50,1))
# c , h =  cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# bound = cv2.drawContours(img, c, -1, (0,255,0), 1)
# print(len(secs))
# extractsec1(det,c,breaks[1],bound)
plt.imshow(bound)
# plt.imshow(secs[0])
# plt.imshow(im[1])
# plt.imshow(small_block[6][3])
# hlen
# breaks
secs[0].shape
# len(small_block[0][3])
# len(secs)
# len(cords)
# draw(bound,sec1list,0,0,breaks[1])
# print(bound.shape)
# breaks
# plt.imshow( bound [BreakPoints(bound,0,1385)[1]: ,:] )
# det = detect( bound [BreakPoints(bound,0,c-50)[1]: ,:] ,"page"+str(page))
# [(((tl1,tl2),(tr1,tr2),(br1,br2),(bl1,bl2)),text) for (((tl1,tl2),(tr1,tr2),(br1,br2),(bl1,bl2)),text) in det if tl2 < breaks[1]]
# Out:
# <img src="data:image/png;base64,..." width="640">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (1348, 1399, 3)

# %%
img[:,1200,0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-22fb8ed6aed7> in <module>
# ----> 1 img[:,1200,0].shape
#
# NameError: name 'img' is not defined

# %%
for (a,b,c,d),y in det:
    image = cv2.circle(bound,a,3,(0,0,255),2)
    image = cv2.circle(image,b,3,(0,255,0),2)
    image = cv2.circle(image,c,3,(255,0,0),2)
    image = cv2.circle(image,d,3,(0,0,0),2)
    
plt.imshow(image)

# %%
#     sec2 = boundary(im[page])
#     if page == 1:
#         sec1 , sec2 = segmentation(sec2)
#         LIST = detect(sec1,"sec1")
#         yy,cords= same(sec1)
#         DATERELEASED = [(307, 383), (524, 411)]
#         RISKID = [(222, 89), (711, 119)]
#         RATINGEFFECTIVE = [(901, 89), (1201, 119)]
#         RATINGLIST = []
#         RISKNAME = [(323, 119), (711, 151)]
#         RISKLIST = []
#         production_date = ""
#         for ind,x in enumerate(LIST):
#             if blockIsIn(x[0],RISKID):
#                 risk_id = x[1]
#             if blockIsIn(x[0],RATINGEFFECTIVE):
#                 RATINGLIST.append(x[1])
#             if blockIsIn(x[0],RISKNAME):
#                 RISKLIST.append(x[1])
#             if "carrier" in x[1].lower():
#                 if ":" in LIST[ind+1][1]:
#                     carrier = LIST[ind+2][1]
#                 else:
#                     carrier = LIST[ind+1][1]
#             if "policy" in x[1].lower():
#                 if ":" in LIST[ind+1][1]:
#                     policy_no = LIST[ind+2][1]
#                 else:
#                     policy_no = LIST[ind+1][1]

#         rating_effective_date = [x for x in RATINGLIST if ("/" in x)][0]
#         risk_name =  " ".join(RISKLIST)
#         state = "0-MI"
# #         print("prd",production_date)
#         production_date = ""

#         temp = {
#                                 "risk_name": risk_name,
#                                 "risk_id": risk_id,
#                                 "rating_effective_date": rating_effective_date,
#                                 "production_date": production_date,
#                                 "state": state,
#                                 "carrier": carrier,
#                                 "policy_no": policy_no,
#                                 "eff_date": "",
#                                 "exp_date": "",
#                                 "code": "",
#                                 "elr": "",
#                                 "dratio": "",
#                                 "payroll": "",
#                                 "expected_losses": "",
#                                 "exp_prim_losses": "",
#                                 "claim_data": "",
#                                 "ij": "",
#                                 "of": "",
#                                 "act_inc_losses": "",
#                                 "act_prim_losses": "",
#                                 "statecode": state,
#                                 "Policy Total": "",
#                                 "Subject Premium": "",
#                                 "Total Act Inc Losses": ""
#                             }
# #         print(temp)
# #         break

#     yy,cords = same(sec2)
#     if len(cords) > 8:
#         I = []
#         for ind,(p1,(x,y)) in enumerate(cords[:8:-1]):
#             diff = (y-p1[1])/2            
#             if x < 200 and x > 135 and diff <16:
#                 I.append(len(cords)-ind-1)
#         if len(I) > 0:
#             sec2 = cv2.line(sec2,(cords[I[-1]][1][0],0),(cords[I[0]][1][0],sec2.shape[0]),(0,0,0),3)
#         sec2 = cv2.line(sec2,(0,sec2.shape[0]),(sec2.shape[1],sec2.shape[0]),(0,0,0),3)
#         LIST = detect(sec2,"sec2")
#         found = True
#         for (box,text) in LIST:
#             if "00/00/00" in text:
#                 found = False
#         print(page,found)
#         if found:
#             break
# #         plt.imshow(sec2)
        
#         for ind,x in enumerate(LIST):
#             if "released" in x[1].lower():
#                 if ":" in LIST[ind+1][1]:
#                     production_date = LIST[ind+2][1]
#                 else:
#                     production_date = LIST[ind+1][1]
#         temp["production_date"] = production_date
#         L = []
#         for ind in range(0,len(cords)):
#             words = []    
#             v = cords[ind]
#             for x in range(len(LIST)):
#                 if isIn(LIST[x][0][1],v) and isIn(LIST[x][0][2],v):
#                     if "00/00/00" in LIST[x][1]:
#                         s = LIST[x][1].split("00/00/00")[-1]
#                         if "" != s:
#                             words.append(s)
#                 if blockIsIn(LIST[x][0],v):
#                     words.append(LIST[x][1])
#                 else:
#                     if len(words) != 0:
#                         L.append("".join(words))
#                         break
#             if len(words) == 0:
#                 L.append("")

#         lines = [[L[x+y] for y in range(12) if x+y<len(L)] for x in range(len(L)) if ('00/00/00' in L[x])] 
#         if len(lines[-1]) != 12:
#             lines[-1].append("")

#         for ind,x in enumerate(lines):
#             if '' == x[0].split("-")[-1]:
#                 lines[ind][0] += '00/00/00'
#         temp_list.extend(extractsec3(lines,temp))
#     break
    
# json["merged_amit_data_edit"] = temp_list
# json_base = []
# json_base.append(json)
# with open(sys.argv[-1]+"/"+path.split("/")[-1].split(".")[0]+'.json', 'w') as fp:
#         j.dump(json_base, fp,indent = 4)

# %%
det
# Out:
# [([[143, 39], [212, 39], [212, 65], [143, 65]], 'Rating'),
#  ([[223, 39], [318, 39], [318, 65], [223, 65]], 'Effective'),
#  ([[328, 39], [376, 39], [376, 65], [328, 65]], 'Date'),
#  ([[380, 38], [383, 38], [383, 64], [380, 64]], ':'),
#  ([[393, 38], [508, 38], [508, 63], [393, 64]], '09/11/2019'),
#  ([[604, 41], [725, 41], [725, 62], [604, 62]], 'Production'),
#  ([[735, 41], [783, 41], [783, 62], [735, 62]], 'Date'),
#  ([[787, 41], [790, 41], [790, 62], [787, 62]], ':'),
#  ([[804, 41], [919, 41], [919, 62], [804, 62]], '07/25/2019'),
#  ([[1004, 41], [1059, 41], [1059, 62], [1004, 62]], 'State'),
#  ([[1063, 41], [1066, 41], [1066, 62], [1063, 62]], ':'),
#  ([[1085, 41], [1227, 41], [1227, 62], [1085, 62]], 'INTERSTATE'),
#  ([[3, 125], [27, 125], [27, 148], [3, 148]], '09'),
#  ([[30, 125], [35, 125], [35, 148], [30, 148]], '-'),
#  ([[38, 125], [140, 125], [140, 148], [38, 148]], 'FLORIDA'),
#  ([[342, 125], [389, 125], [389, 146], [342, 146]], 'Firm'),
#  ([[399, 125], [419, 125], [419, 146], [399, 146]], 'ID'),
#  ([[424, 125], [427, 125], [427, 146], [424, 146]], ':'),
#  ([[492, 124], [539, 124], [539, 146], [492, 146]], 'Firm'),
#  ([[550, 124], [611, 124], [611, 146], [550, 146]], 'Name'),
#  ([[615, 124], [618, 124], [618, 146], [615, 146]], ':'),
#  ([[637, 124], [764, 124], [764, 146], [637, 146]], 'EMPLOYER'),
#  ([[774, 124], [880, 124], [880, 146], [774, 146]], 'PAYROLL'),
#  ([[889, 124], [1022, 124], [1022, 146], [889, 146]], 'SOLUTIONS'),
#  ([[1033, 124], [1069, 124], [1069, 146], [1033, 146]], 'INC'),
#  ([[4, 175], [79, 175], [79, 196], [4, 196]], 'Carrier'),
#  ([[83, 175], [85, 175], [85, 196], [83, 196]], ':'),
#  ([[116, 175], [175, 175], [175, 196], [116, 196]], '39071'),
#  ([[654, 175], [683, 175], [683, 196], [654, 196]], 'Eff'),
#  ([[692, 175], [740, 175], [740, 196], [692, 196]], 'Date'),
#  ([[744, 175], [747, 175], [747, 196], [744, 196]], ':'),
#  ([[793, 175], [906, 175], [906, 196], [793, 196]], '10/01/2015'),
#  ([[13, 214], [66, 214], [66, 234], [13, 234]], 'Code'),
#  ([[90, 214], [131, 214], [131, 234], [90, 234]], 'ELR'),
#  ([[754, 375], [754, 370], [774, 369], [774, 374]], 'ܘ'),
#  ([[546, 400], [576, 400], [576, 418], [546, 418]], '-12'),
#  ([[756, 462], [754, 408], [775, 407], [777, 461]], 'olo'),
#  ([[754, 375], [754, 370], [774, 369], [774, 374]], 'o'),
#  ([[13, 399], [58, 399], [58, 421], [13, 421]], '9841'),
#  ([[75, 399], [134, 399], [134, 421], [75, 421]], 'DRUG'),
#  ([[147, 399], [152, 399], [152, 421], [147, 421]], '-'),
#  ([[153, 399], [208, 399], [208, 421], [153, 421]], 'FREE'),
#  ([[217, 399], [342, 399], [342, 421], [217, 421]], 'WORKPLAC'),
#  ([[13, 438], [61, 438], [61, 460], [13, 460]], '9848'),
#  ([[75, 438], [176, 438], [176, 460], [75, 460]], 'MINIMUM'),
#  ([[187, 438], [287, 438], [287, 460], [187, 460]], 'PREMIUM'),
#  ([[298, 438], [325, 438], [325, 460], [298, 460]], 'FO'),
#  ([[397, 475], [485, 475], [485, 501], [397, 501]], 'Subject'),
#  ([[-7, 502], [71, 500], [72, 528], [-6, 530]], 'Policy'),
#  ([[78, 500], [132, 499], [133, 526], [79, 527]], 'Total'),
#  ([[137, 499], [140, 499], [141, 526], [138, 526]], ':'),
#  ([[318, 502], [396, 501], [396, 527], [318, 528]], '296,686'),
#  ([[402, 501], [499, 500], [499, 526], [402, 527]], 'Premium'),
#  ([[504, 501], [506, 501], [506, 526], [504, 526]], ':'),
#  ([[787, 475], [846, 475], [846, 496], [787, 496]], 'Total'),
#  ([[855, 475], [891, 475], [891, 496], [855, 496]], 'Act'),
#  ([[900, 475], [931, 475], [931, 496], [900, 496]], 'Inc'),
#  ([[739, 503], [773, 503], [773, 523], [739, 523]], '862'),
#  ([[786, 503], [870, 503], [870, 523], [786, 523]], 'Losses'),
#  ([[873, 503], [878, 503], [878, 523], [873, 523]], ':')]

# %%
inorderminus1 = []
for _,x in det:
    try:
#         print(x)
        x = int(x.replace(",",""))
        inorderminus1.append("ABC "+str(x))
    except:
        pass
inorderminus1.append("")
inorderminus1
# Out:
# ['ABC 9',
#  'ABC 30406',
#  'ABC 8',
#  'ABC 284220',
#  'ABC 4803',
#  'ABC 1873',
#  'ABC 94023',
#  'ABC 17000',
#  'ABC 35',
#  'ABC 83048',
#  'ABC 1320',
#  'ABC 451',
#  'ABC 451',
#  'ABC 594',
#  'ABC 1936',
#  'ABC 6',
#  'ABC 37',
#  'ABC 4965',
#  'ABC 962',
#  'ABC 962',
#  'ABC 212165',
#  'ABC 374398',
#  'ABC 173',
#  'ABC 1498',
#  'ABC 674',
#  'ABC 1286',
#  'ABC 1286',
#  'ABC 173',
#  'ABC 259724',
#  'ABC 1039',
#  'ABC 468',
#  'ABC 173',
#  'ABC 40',
#  'ABC 53907',
#  'ABC 216',
#  'ABC 97',
#  'ABC 173',
#  'ABC 40',
#  'ABC 33821',
#  'ABC 135',
#  'ABC 61',
#  'ABC 173',
#  'ABC 40',
#  'ABC 78790',
#  'ABC 315',
#  'ABC 142',
#  'ABC 930',
#  'ABC 0',
#  'ABC 0',
#  'ABC 2105',
#  'ABC 167335',
#  'ABC 3564',
#  'ABC 1604',
#  'ABC 3040',
#  'ABC 4496',
#  'ABC 1619',
#  'ABC 156658',
#  'ABC 20332',
#  'ABC 3179',
#  'ABC 207',
#  'ABC 93',
#  'ABC 3724',
#  'ABC 15775',
#  'ABC 205',
#  'ABC 66',
#  'ABC 3724',
#  'ABC 8915',
#  'ABC 2853',
#  'ABC 4299',
#  'ABC 685806',
#  'ABC 93063',
#  'ABC 33410',
#  'ABC 912',
#  'ABC 410',
#  'ABC 5022',
#  'ABC 1286',
#  'ABC 412',
#  'ABC 5102',
#  'ABC 77346',
#  'ABC 2266',
#  'ABC 725',
#  'ABC 5190',
#  'ABC 69464',
#  'ABC 1278',
#  'ABC 460',
#  'ABC 5221',
#  'ABC 8060',
#  'ABC 222',
#  'ABC 80',
#  'ABC 5221',
#  'ABC 6520',
#  'ABC 180',
#  'ABC 65',
#  'ABC 5221',
#  'ABC 1000',
#  'ABC 28',
#  'ABC 10',
#  'ABC 5223',
#  'ABC 4085',
#  'ABC 95',
#  'ABC 34',
#  'ABC 5445',
#  'ABC 30980',
#  'ABC 867',
#  'ABC 277',
#  'ABC 5445',
#  'ABC 2040',
#  'ABC 57',
#  'ABC 18',
#  'ABC 5474',
#  'ABC 1203',
#  'ABC 385',
#  'ABC 5474',
#  'ABC 36019',
#  'ABC 192148',
#  'ABC 13403',
#  'ABC 6418',
#  'ABC 2054',
#  'ABC 5474',
#  'ABC 448',
#  'ABC 143',
#  'ABC 5537',
#  'ABC 36753',
#  'ABC 845',
#  'ABC 304',
#  'ABC 6400',
#  'ABC 920',
#  'ABC 31',
#  'ABC 12',
#  'ABC 8001',
#  'ABC 39996',
#  'ABC 760',
#  'ABC 342',
#  'ABC 8018',
#  'ABC 66779',
#  'ABC 955',
#  'ABC 430',
#  'ABC 8102',
#  'ABC 88240',
#  'ABC 1077',
#  'ABC 485',
#  'ABC 8209',
#  'ABC 306629',
#  'ABC 7911',
#  'ABC 3402',
#  'ABC 8380',
#  'ABC 95210',
#  'ABC 1200',
#  'ABC 480',
#  'ABC 8723',
#  'ABC 30362',
#  'ABC 24',
#  'ABC 10',
#  'ABC 8742',
#  'ABC 14',
#  'ABC 361',
#  'ABC 31',
#  'ABC 260',
#  'ABC 44',
#  'ABC 16',
#  '']

# %%
extract3(inorderminus1,temp)
# Out:
# {'risk_name': 'EMPLOYER PAYROLL SOLUTIONS INC',
#  'risk_id': '914245192',
#  'rating_effective_date': '09/11/2019',
#  'production_date': '07/25/2019',
#  'state': 'INTERSTATE',
#  'carrier': '39071',
#  'policy_no': 'TWC3509986',
#  'eff_date': '10/01/2015',
#  'exp_date': '10/01/2016',
#  'code': '',
#  'elr': '',
#  'dratio': '',
#  'payroll': '',
#  'expected_losses': '',
#  'exp_prim_losses': '',
#  'claim_data': '',
#  'ij': '',
#  'of': '',
#  'act_inc_losses': '',
#  'act_prim_losses': '',
#  'statecode': '09 - FLORIDA',
#  'Policy Total': 6418754,
#  'Subject Premium': 198585,
#  'Total Act Inc Losses': 547521}

# %%
#  ([[145, 1554], [147, 1554], [147, 1563], [145, 1563]], 'ה'),
#  ([[114, 1554], [133, 1554], [133, 1563], [114, 1563]], 'וח'),
#  ([[75, 1554], [101, 1554], [101, 1563], [75, 1563]], 'IFA'),
#  ([[107, 1554], [109, 1554], [109, 1563], [107, 1563]], 'A')]

# %%
# !pip install proto-google-cloud-vision-v1
# Out:
# Collecting proto-google-cloud-vision-v1
#   Downloading proto-google-cloud-vision-v1-0.90.3.tar.gz (18 kB)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.5.2 in c:\anaconda\lib\site-packages (from proto-google-cloud-vision-v1) (1.53.0)
# Collecting oauth2client<4.0dev,>=2.0.0
#   Downloading oauth2client-3.0.0.tar.gz (77 kB)
# Requirement already satisfied: protobuf>=3.12.0 in c:\anaconda\lib\site-packages (from googleapis-common-protos<2.0dev,>=1.5.2->proto-google-cloud-vision-v1) (3.18.0)
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.20.1-py3-none-any.whl (96 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in c:\anaconda\lib\site-packages (from oauth2client<4.0dev,>=2.0.0->proto-google-cloud-vision-v1) (0.4.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in c:\anaconda\lib\site-packages (from oauth2client<4.0dev,>=2.0.0->proto-google-cloud-vision-v1) (0.2.8)
# Requirement already satisfied: rsa>=3.1.4 in c:\anaconda\lib\site-packages (from oauth2client<4.0dev,>=2.0.0->proto-google-cloud-vision-v1) (4.7.2)
# Requirement already satisfied: six>=1.6.1 in c:\anaconda\lib\site-packages (from oauth2client<4.0dev,>=2.0.0->proto-google-cloud-vision-v1) (1.15.0)
# Requirement already satisfied: pyparsing<3,>=2.4.2 in c:\anaconda\lib\site-packages (from httplib2>=0.9.1->oauth2client<4.0dev,>=2.0.0->proto-google-cloud-vision-v1) (2.4.7)
# Building wheels for collected packages: proto-google-cloud-vision-v1, oauth2client
#   Building wheel for proto-google-cloud-vision-v1 (setup.py): started
#   Building wheel for proto-google-cloud-vision-v1 (setup.py): finished with status 'done'
#   Created wheel for proto-google-cloud-vision-v1: filename=proto_google_cloud_vision_v1-0.90.3-py3-none-any.whl size=24169 sha256=b9b205212ecd75ace3440d82d10c38c149ba7c7d001d9ec46aae2c61dd09f65a
#   Stored in directory: c:\users\daniyal's pc\appdata\local\pip\cache\wheels\e5\9c\c9\14acefbfb17c0aa1420c0874026c37aa0e3ad088f274506ac8
#   Building wheel for oauth2client (setup.py): started
#   Building wheel for oauth2client (setup.py): finished with status 'done'
#   Created wheel for oauth2client: filename=oauth2client-3.0.0-py3-none-any.whl size=106381 sha256=e1dec65b7aa839fc5544b526bd04ef15e0e8e487b2b4809687afd827d4a81915
#   Stored in directory: c:\users\daniyal's pc\appdata\local\pip\cache\wheels\72\35\a1\4e0e05c5c381fdf1429312cd38e37a305bd18bd6118037cd5a
# Successfully built proto-google-cloud-vision-v1 oauth2client
# Installing collected packages: httplib2, oauth2client, proto-google-cloud-vision-v1
# Successfully installed httplib2-0.20.1 oauth2client-3.0.0 proto-google-cloud-vision-v1-0.90.3

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS="C:\Users\DANIYAL's PC\Desktop\Ramish\nirav9033688351-attachments\nirav9033688351-attachments"
# Out:
# 'export' is not recognized as an internal or external command,
# operable program or batch file.
